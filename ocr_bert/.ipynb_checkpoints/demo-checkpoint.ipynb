# %%
from test_ocr import init_ocr_model,ocr_img
import csv
import os
import time



# 假设我们要写入的是以下两行数据
dir_path = os.getcwd()

# 文件头，一般就是数据名
fileHeader = ["图片", "商铺名称"]
# 写入数据

csvFile = open("company.csv", "a")
writer = csv.writer(csvFile)

# 写入的内容都是以列表的形式传入函数
writer.writerow(fileHeader)

csvFile.close()

ocr_detection_model, ocr_recognition_model, ocr_label_dict = init_ocr_model()

def ocr_test(i):
    UPLOAD_FOLDER = './uploads'
    IMAGE_FOLDER = './image'
    VIDEO_FOLDER = r'./video'
    FOND_PATH = '/ocr/STXINWEI.TTF'
    # for i in range(14,51):

    ALLOWED_EXTENSIONS = set(['txt', 'pdf', 'png', 'jpg', 'jpeg', 'gif', 'mp4','avi'])
    VIDEO_EXTENSIONS = set(['mp4', 'avi'])
    img_path = dir_path+"/ocr/image/images/" + str(i) + ".jpg"
    save_path = dir_path+"/ocr/image/test_img/"+ str(i) + ".jpg"
    result = ocr_img(img_path,save_path, ocr_detection_model, ocr_recognition_model, ocr_label_dict)
    return result

from bert_ner import bert_ner_text

def companyText(re,n):
    result_str = ''
    for i in range(0,len(re)):
        result_a = ''
        for j in range(0,len(re[i])):
            result_a+=re[i][j]
        result_str+=result_a
        result_str+=','

    company_text = bert_ner_text(result_str)
    print(company_text)
    d1 = [str(n)+'.jpg', company_text]
    csv_file = open("company.csv", "a")
    writer = csv.writer(csv_file)
    writer.writerow(d1)
    csv_file.close()

# %%
for n in range(1,51):
    start_time = time.time()
    i = str(n)
    re = ocr_test(i)
    companyText(re,i)
    end_time = time.time()
    print("使用时间：",end_time-start_time,'s')
# Out:
# (771, 1485, 3)
# 0 1 7 长扬汽车修理厂
# 长扬汽车修理厂
# 使用时间： 0.8351397514343262 s
# (2332, 3484, 3)
# 0 1 4 德成商店
# 德成商店
# 使用时间： 8.745046615600586 s
# (1936, 2592, 3)
# 0 1 2 华硕
# 华硕
# 使用时间： 7.401079416275024 s
# (1080, 760, 3)
# 0 1 3 欧维思
# 欧维思
# 使用时间： 0.7597670555114746 s
# (666, 500, 3)
# 0 1 5 有家烧烤店
# 有家烧烤店
# 使用时间： 0.8200838565826416 s
# (540, 960, 3)
# 0 1 8 宏峰五金建材商店
# 宏峰五金建材商店
# 使用时间： 1.4117217063903809 s
# (375, 500, 3)
# 0 1 4 兰州拉面
# 兰州拉面
# 使用时间： 1.2463181018829346 s
# (358, 500, 3)
# 0 1 4 链家地产
# 链家地产
# 使用时间： 0.5233757495880127 s
# (485, 650, 3)
# 0 1 3 超意兴
# 超意兴
# 使用时间： 1.3814129829406738 s
# (517, 690, 3)
# 0 1 3 肯德基
# 肯德基
# 使用时间： 0.4734010696411133 s
# (666, 500, 3)
# 0 1 6 蓓佳社区超市
# 蓓佳社区超市
# 使用时间： 0.5180084705352783 s
# (972, 1296, 3)
# 0 1 7 泰利达百货商店
# 泰利达百货商店
# 使用时间： 1.058868408203125 s
# (727, 1082, 3)
# 0 16 19 ZHOU
# ZHOU
# 使用时间： 0.7254679203033447 s
# (360, 640, 3)
# 0 1 3 超意兴
# 超意兴
# 使用时间： 0.9871256351470947 s
# (810, 1080, 3)
# 0 1 4 兄弟卤菜
# 兄弟卤菜
# 使用时间： 1.3197274208068848 s
# (633, 766, 3)
# 0 1 5 老三旺菜馆
# 老三旺菜馆
# 使用时间： 0.714646577835083 s
# (300, 400, 3)
# 0 19 24 光青水电汽车
# 光青水电汽车
# 使用时间： 0.8091027736663818 s
# (1109, 1843, 3)
# 0 1 8 泛华金融服务集团
# 泛华金融服务集团
# 使用时间： 1.4833474159240723 s
# (375, 500, 3)
# 0 1 5 一品鲜饭店
# 一品鲜饭店
# 使用时间： 0.7726223468780518 s
# (300, 533, 3)
# 0 9 10 农行
# 农行
# 使用时间： 0.5198044776916504 s
# (600, 800, 3)
# 0 1 4 正新鸡排
# 正新鸡排
# 使用时间： 1.583092451095581 s
# (725, 630, 3)
# 0 1 12 联通旗舰营业厅,Cind
# 联通旗舰营业厅,Cind
# 使用时间： 0.9146730899810791 s
# (782, 664, 3)
# 0 6 17 HAIRDRESSING
# HAIRDRESSING
# 使用时间： 0.8566775321960449 s
# (360, 500, 3)
# 0 1 12 张家港市长顺贸易有限公司
# 张家港市长顺贸易有限公司
# 使用时间： 0.4524655342102051 s
# (375, 500, 3)
# 0 1 3 舒雅居
# 舒雅居
# 使用时间： 0.5881659984588623 s
# (375, 500, 3)
# 0 1 4 盈鼎房产
# 盈鼎房产
# 使用时间： 0.7080397605895996 s
# (665, 947, 3)
# 0 1 5 杨宗清诊所
# 杨宗清诊所
# 使用时间： 1.1978003978729248 s
# (375, 500, 3)
# 0 1 11 博思特家政服务有限公司
# 博思特家政服务有限公司
# 使用时间： 0.7215940952301025 s
# (480, 640, 3)
# 0 1 10 中华联合财产保险公司
# 中华联合财产保险公司
# 使用时间： 0.9520432949066162 s
# (1195, 1801, 3)
# 0 1 9 INSTITUTE
# INSTITUTE
# 使用时间： 1.480421543121338 s
# (443, 590, 3)
# 0 1 7 辅延中心幼儿园
# 辅延中心幼儿园
# 使用时间： 0.59360671043396 s
# (1080, 1440, 3)
# 0 1 6 跃航培训学校
# 跃航培训学校
# 使用时间： 1.186868667602539 s
# (1100, 1467, 3)
# 0 1 4 桂南驾校
# 桂南驾校
# 使用时间： 2.021857738494873 s
# (331, 500, 3)
# 0 1 8 白马井镇中心学校
# 白马井镇中心学校
# 使用时间： 0.4545862674713135 s
# (341, 540, 3)
# 0 1 4 如家酒店
# 如家酒店
# 使用时间： 0.5411255359649658 s
# (285, 470, 3)
# 0 1 6 7天连锁酒店
# 7天连锁酒店
# 使用时间： 0.42328572273254395 s
# (300, 533, 3)
# 0 4 11 时尚仙雄美容客院
# 时尚仙雄美容客院
# 使用时间： 0.44640421867370605 s
# (1104, 3264, 3)
# 0 6 10 镜花缘餐厅
# 镜花缘餐厅
# 使用时间： 1.1140329837799072 s
# (375, 500, 3)
# 0 1 4 福建沙县
# 福建沙县
# 使用时间： 0.70625901222229 s
# (433, 650, 3)
# 0 1 3 伦巴萨
# 伦巴萨
# 使用时间： 0.7791016101837158 s
# (1078, 1920, 3)
# 0 1 11 博格纳金属材料有限公司
# 博格纳金属材料有限公司
# 使用时间： 1.7046098709106445 s
# (853, 1280, 3)
# 0 1 3 星巴克
# 星巴克
# 使用时间： 0.4908273220062256 s
# (535, 782, 3)
# 0 1 5 益丰大药房
# 益丰大药房
# 使用时间： 1.1905195713043213 s
# (475, 640, 3)
# 0 16 20 SHUYU
# SHUYU
# 使用时间： 1.0593206882476807 s
# (303, 500, 3)
# 0 1 6 鼎兴百货超市
# 鼎兴百货超市
# 使用时间： 0.594139814376831 s
# (425, 640, 3)
# 0 1 4 华联超市
# 华联超市
# 使用时间： 0.7398374080657959 s
# (570, 821, 3)
# 0 1 4 海澜之家
# 海澜之家
# 使用时间： 0.7599058151245117 s
# (1296, 1728, 3)
# 0 1 4 杭州银行
# 杭州银行
# 使用时间： 1.0176825523376465 s
# (1200, 1600, 3)
# 0 1 6 中国工商银行
# 中国工商银行
# 使用时间： 0.8670830726623535 s
# (1843, 1109, 3)
# 0 1 9 通县节能技术推广站
# 通县节能技术推广站
# 使用时间： 0.6838724613189697 s

# %%
import pandas as pd
csv2Excel = pd.read_csv('company.csv', encoding='utf-8')
csv2Excel.to_excel(r'company.xlsx', sheet_name='data')

# %%
# 导入模型权重

result_str = ''
for i in range(0,len(re)):
    result_a = ''
    for j in range(0,len(re[i])):
        result_a+=re[i][j]
    result_str+=result_a
    result_str+=','

print(result_str)

company_text = bert_ner_text(result_str)

# %%
print(company_text)
# Out:
# 有家烧烤店
